# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
import datetime as dt
import nltk as nltk
from dotenv import load_dotenv
from datetime import datetime
from newsapi import NewsApiClient
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from collections import Counter
from nltk import ngrams

analyzer = SentimentIntensityAnalyzer()
nltk.download('vader_lexicon')

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\AdamF\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv()
api_key = os.getenv("NEWS_API_KEY")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
en_bitcoin_articles = newsapi.get_everything(
    q="Bitcoin AND bitcoin AND BTC",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# Check the total number of news articles featuring Bitcoin
print(f"Total number of news articles featuring Bitcoin, bitcoin or BTC - {en_bitcoin_articles['totalResults']}")

# Print the tenth Bitcoin news article as a sample for inspection
print(f"Sample news article featuring Bitcoin, bitcoin or BTC - {en_bitcoin_articles['articles'][9]}")
# Out:
# Total number of news articles featuring Bitcoin, bitcoin or BTC - 1677
# Sample news article featuring Bitcoin, bitcoin or BTC - {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Vildana Hajric and Emily Graffeo', 'title': 'Bitcoin Death Cross Is Staring Down Bulls After a Painful Retreat - Yahoo Canada Finance', 'description': '(Bloomberg) -- After one of the roughest patches ever for Bitcoin enthusiasts, holders of the largest digital currency are facing an ominous technical price ...', 'url': 'https://ca.finance.yahoo.com/news/bitcoin-death-cross-staring-down-143445162.html', 'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/FF0U6cXA4WCLbMISLFvgvg--~B/aD02NzU7dz0xMjAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/bloomberg_markets_842/73c5ba4da2abe15d515c3f4646c64653', 'publishedAt': '2022-01-11T19:45:20Z', 'content': '(Bloomberg) -- After one of the roughest patches ever for Bitcoin enthusiasts, holders of the largest digital currency are facing an ominous technical price pattern with a name that suggests more pai… [+4176 chars]'}

# %%
# Fetch the Ethereum news articles
en_ethereum_articles = newsapi.get_everything(
    q="Ethereum AND ethereum AND ETH",
    language='en',
    page_size=100,
    sort_by="relevancy"
)

# Check the total number of news articles featuring Ethereum
print(f"Total number of news articles featuring Ethereum, ethereum or ETH - {en_ethereum_articles['totalResults']}")

# Print the tenth Ethereum news article as a sample for inspection
print(f"Sample news article featuring Ethereum, ethereum or ETH - {en_ethereum_articles['articles'][6]}")
# Out:
# Total number of news articles featuring Ethereum, ethereum or ETH - 798
# Sample news article featuring Ethereum, ethereum or ETH - {'source': {'id': 'time', 'name': 'Time'}, 'author': 'Andrew R. Chow', 'title': 'How Blockchain Could Solve the Problem of Digital Identity', 'description': 'When Vitalik Buterin, the founder of Ethereum, has been asked lately about his favorite projects being built on the blockchain, he often names Proof of Humanity.', 'url': 'https://time.com/6142810/proof-of-humanity/', 'urlToImage': 'https://api.time.com/wp-content/uploads/2022/01/IMG_3792.jpeg?quality=85&crop=0px%2C273px%2C1125px%2C588px&resize=1200%2C628&strip', 'publishedAt': '2022-01-27T09:39:28Z', 'content': 'A version of this article was published in TIME’s newsletter Into the Metaverse. Subscribe for a weekly guide to the future of the Internet.You can find past issues of the newsletter here.\r\nWhen Vita… [+9697 chars]'}

# %%
# Create the Bitcoin sentiment scores DataFrame
# Create empty list to populate with article details and sentiment scores
bitcoin_sentiments = []

# Get required details from articles response returned by api 
for article in en_bitcoin_articles["articles"]:
    try:
        text = article["content"].lower()
        title = article["title"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        # Add article details as dicts to bitcoin_sentiments list
        bitcoin_sentiments.append({
            "Title": title,
            "Text": text,
            "Date": date,
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu,
            
        })
        
    except AttributeError:
        pass
    
# Create Bitcoin Sentiments DataFrame from the bitcoin_sentiments list of dicts
bitcoin_df = pd.DataFrame(bitcoin_sentiments)

# Inspect the DataFrame
bitcoin_df.head()
# Out:
#                                                Title  \
# 0  Crypto.com admits over $30 million stolen by h...
# 1  Bitcoin slumps to lowest since September - Reu...
# 2  BUZZ Crypto stocks slip as bitcoin briefly sli...
# 3  Crypto investors buy the dip as Bitcoin falls ...
# 4  Bitcoin death cross is staring down bulls afte...
#
#                                                 Text        Date  Compound  \
# 0  in a new blog post the company said that 4,836...  2022-01-20    0.0000
# 1  london, jan 7 (reuters) - bitcoin on friday sl...  2022-01-07   -0.3818
# 2  ** shares of cryptocurrency and blockchain-rel...  2022-01-10    0.3818
# 3  welcome to kitco news' 2022 outlook series. th...  2022-01-10    0.1531
# 4  after one of roughest patches ever for bitcoin...  2022-01-11   -0.5563
#
#    Positive  Negative  Neutral
# 0     0.000     0.000    1.000
# 1     0.000     0.077    0.923
# 2     0.128     0.057    0.815
# 3     0.076     0.061    0.863
# 4     0.063     0.156    0.781

# %%
# Create the Ethereum sentiment scores DataFrame
# Create empty list to populate with article details and sentiment scores
ethereum_sentiments = []

# Get required details from articles response returned by api 
for article in en_ethereum_articles["articles"]:
    try:
        text = article["content"].lower()
        title = article["title"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        # Add article details as dicts to ethereum_sentiments list
        ethereum_sentiments.append({
            "Text": text,
            "Title Ehterum": title,
            "Date": date,
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu,
            "Title": title,
        })
        
    except AttributeError:
        pass
    
# Create Ethereum Sentiments DataFrame from the bitcoin_sentiments list of dicts
ethereum_df = pd.DataFrame(ethereum_sentiments)

# Inspect the DataFrame
ethereum_df.head()
# Out:
#                                                 Text  \
# 0  in a new blog post the company said that 4,836...
# 1  in an interview with bloomberg tv, crypto.com'...
# 2  online thieves made off with "wrapped ethereum...
# 3  online thieves made off with 120,000 weth, or ...
# 4  the crypto market's whiplash volatility can ma...
#
#                                        Title Ehterum        Date  Compound  \
# 0  Crypto.com admits over $30 million stolen by h...  2022-01-20    0.0000
# 1  Crypto.com loses $34 million in hack that affe...  2022-01-20    0.1027
# 2  Blockchain platform Wormhole says it's retriev...  2022-02-03    0.1027
# 3  Hacker steals over $320M from blockchain platf...  2022-02-03   -0.6808
# 4  Crypto Exchange Shuts Down Withdrawals After H...  2022-01-19    0.5574
#
#    Positive  Negative  Neutral  \
# 0     0.000     0.000    1.000
# 1     0.046     0.000    0.954
# 2     0.131     0.092    0.778
# 3     0.051     0.174    0.775
# 4     0.129     0.000    0.871
#
#                                                Title
# 0  Crypto.com admits over $30 million stolen by h...
# 1  Crypto.com loses $34 million in hack that affe...
# 2  Blockchain platform Wormhole says it's retriev...
# 3  Hacker steals over $320M from blockchain platf...
# 4  Crypto Exchange Shuts Down Withdrawals After H...

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#          Compound    Positive    Negative     Neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.033542    0.056200    0.046490    0.897320
# std      0.400954    0.062165    0.056293    0.075037
# min     -0.802000    0.000000    0.000000    0.712000
# 25%     -0.273200    0.000000    0.000000    0.847750
# 50%      0.000000    0.056000    0.000000    0.907000
# 75%      0.361200    0.090250    0.086000    0.945000
# max      0.835700    0.233000    0.204000    1.000000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#          Compound    Positive    Negative     Neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.132503    0.084820    0.052770    0.862410
# std      0.451053    0.069577    0.069539    0.090543
# min     -0.868900    0.000000    0.000000    0.596000
# 25%     -0.109025    0.000000    0.000000    0.798000
# 50%      0.184000    0.079500    0.000000    0.865000
# 75%      0.476700    0.131000    0.093750    0.930250
# max      0.858800    0.309000    0.257000    1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: ***The analysis demonstrates that Ethereum has the highest mean positive score.***
#
# Q: Which coin had the highest compound score?
#
# A: ***The analysis demonstrates that Ethereum has the highest compound score.***
#
# Q. Which coin had the highest positive score?
#
# A: ***The analysis demonstrates that Ethereum has the highest positive score.***

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
sw = set(stopwords.words('english'))

# Expand the default stopwords list if necessary
sw_addon = {'urlToImage','url','char','ha'}

# %%
 # Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
   
    # Create a tokenized list of the words
    words = word_tokenize(re_clean)
    
    # Lemmatize words into root words
    lemmatizer = WordNetLemmatizer() 
    lem = [lemmatizer.lemmatize(word) for word in words]
    
    # Remove the stop words and convert the words to lowercase
    tokens = [word.lower() for word in lem if word.lower() not in sw.union(sw_addon)]
    
    return tokens

# %%
# Create a new tokens column for bitcoin
# Copy the Bitcoin DF ready to add Tokens new column
bitcoin_tokens_df = bitcoin_df.copy()

# Create empty tokenized list
tokenized = []

# Tokenize the "Text" column for each row of the DataFrame
for article in bitcoin_tokens_df['Text']:
    # Use the tokenizer function to tokenize the article
    tokenized_articles = tokenizer(article)
    # Append all tokens to the tokenized list of dicts
    tokenized.append({'tokens':tokenized_articles})

# Create DataFrame of tokens for each article
tokens_df= pd.DataFrame(tokenized)

# Combine the Tokens dataframe with the original
bitcoin_tokens_df['Tokens'] = tokens_df

# Inspect the DataFrame
bitcoin_tokens_df.head()
# Out:
#                                                Title  \
# 0  Crypto.com admits over $30 million stolen by h...
# 1  Bitcoin slumps to lowest since September - Reu...
# 2  BUZZ Crypto stocks slip as bitcoin briefly sli...
# 3  Crypto investors buy the dip as Bitcoin falls ...
# 4  Bitcoin death cross is staring down bulls afte...
#
#                                                 Text        Date  Compound  \
# 0  in a new blog post the company said that 4,836...  2022-01-20    0.0000
# 1  london, jan 7 (reuters) - bitcoin on friday sl...  2022-01-07   -0.3818
# 2  ** shares of cryptocurrency and blockchain-rel...  2022-01-10    0.3818
# 3  welcome to kitco news' 2022 outlook series. th...  2022-01-10    0.1531
# 4  after one of roughest patches ever for bitcoin...  2022-01-11   -0.5563
#
#    Positive  Negative  Neutral  \
# 0     0.000     0.000    1.000
# 1     0.000     0.077    0.923
# 2     0.128     0.057    0.815
# 3     0.076     0.061    0.863
# 4     0.063     0.156    0.781
#
#                                               Tokens
# 0  [new, blog, post, company, said, eth, bitcoin,...
# 1  [london, jan, reuters, bitcoin, friday, slumpe...
# 2  [share, cryptocurrency, blockchainrelated, fir...
# 3  [welcome, kitco, news, outlook, series, new, y...
# 4  [one, roughest, patch, ever, bitcoin, enthusia...

# %%
# Create a new tokens column for Ethereum
# Copy the Ethereum DF ready to add Tokens new column
ethereum_tokens_df = ethereum_df.copy()

# Create empty tokenized list
tokenized = []

# Tokenize the "Text" column for each row of the DataFrame
for article in ethereum_tokens_df['Text']:
    # Use the tokenizer function to tokenize the article
    tokenized_articles = tokenizer(article)
    # Append all tokens to the tokenized list of dicts
    tokenized.append({'tokens':tokenized_articles})

# Create DataFrame of tokens for each article
tokens_df= pd.DataFrame(tokenized)

# Combine the Tokens dataframe with the original
ethereum_tokens_df['Tokens'] = tokens_df

# Inspect the DataFrame
ethereum_tokens_df.head()
# Out:
#                                                 Text  \
# 0  in a new blog post the company said that 4,836...
# 1  in an interview with bloomberg tv, crypto.com'...
# 2  online thieves made off with "wrapped ethereum...
# 3  online thieves made off with 120,000 weth, or ...
# 4  the crypto market's whiplash volatility can ma...
#
#                                        Title Ehterum        Date  Compound  \
# 0  Crypto.com admits over $30 million stolen by h...  2022-01-20    0.0000
# 1  Crypto.com loses $34 million in hack that affe...  2022-01-20    0.1027
# 2  Blockchain platform Wormhole says it's retriev...  2022-02-03    0.1027
# 3  Hacker steals over $320M from blockchain platf...  2022-02-03   -0.6808
# 4  Crypto Exchange Shuts Down Withdrawals After H...  2022-01-19    0.5574
#
#    Positive  Negative  Neutral  \
# 0     0.000     0.000    1.000
# 1     0.046     0.000    0.954
# 2     0.131     0.092    0.778
# 3     0.051     0.174    0.775
# 4     0.129     0.000    0.871
#
#                                                Title  \
# 0  Crypto.com admits over $30 million stolen by h...
# 1  Crypto.com loses $34 million in hack that affe...
# 2  Blockchain platform Wormhole says it's retriev...
# 3  Hacker steals over $320M from blockchain platf...
# 4  Crypto Exchange Shuts Down Withdrawals After H...
#
#                                               Tokens
# 0  [new, blog, post, company, said, eth, bitcoin,...
# 1  [interview, bloomberg, tv, cryptocoms, chief, ...
# 2  [online, thief, made, wrapped, ethereum, worth...
# 3  [online, thief, made, weth, wrapped, ethereum,...
# 4  [crypto, market, whiplash, volatilitycan, make...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
# Generate the Bitcoin N-grams where N=2
bitcoin_bigrams = [Counter(ngrams(tokens, n=2)) for tokens in bitcoin_tokens_df["Tokens"]]

# Print Bigrams dict for fifth article for inspection 
print(dict(bitcoin_bigrams[5]))
# Out:
# {('bitcoin', 'slumped'): 1, ('slumped', 'wednesday'): 1, ('wednesday', 'thursdayjirapong'): 1, ('thursdayjirapong', 'manustronggetty'): 1, ('manustronggetty', 'imagesbitcoin'): 1, ('imagesbitcoin', 'wa'): 1, ('wa', 'thursday'): 1, ('thursday', 'cryptocurrency'): 1, ('cryptocurrency', 'market'): 1, ('market', 'wa'): 1, ('wa', 'sea'): 1, ('sea', 'red'): 1, ('red', 'minute'): 1, ('minute', 'revealed'): 1, ('revealed', 'federa'): 1}

# %%
# Generate the Ethereum N-grams where N=2
ethereum_bigrams = [Counter(ngrams(tokens, n=2)) for tokens in ethereum_tokens_df["Tokens"]]

# Print Bigrams dict for fifth article for inspection 
print(dict(ethereum_bigrams[5]))
# Out:
# {('bug', 'appears'): 1, ('appears', 'present'): 1, ('present', 'week'): 1, ('week', 'seems'): 1, ('seems', 'referenced'): 1, ('referenced', 'least'): 1, ('least', 'one'): 1, ('one', 'tweet'): 1, ('tweet', 'january'): 1, ('january', 'st'): 1, ('st', 'exploitation'): 1, ('exploitation', 'bug'): 1, ('bug', 'picked'): 1, ('picked', 'significantly'): 1, ('significantly', 'past'): 1, ('past', 'day'): 1, ('day', 'blockc'): 1}

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
# Create empty list which will hold tokens fron all articles 
bitcoin_all_tokens = []

# Loop through tokens from all articles and add into all_tokens list
for tokens in bitcoin_tokens_df["Tokens"]:
    bitcoin_all_tokens += tokens

# Use the token_count function to retun the top 10 words and counts  
bitcoin_top10_words = token_count(bitcoin_all_tokens)
bitcoin_top10_words
# Out:
# [('bitcoin', 88),
#  ('market', 27),
#  ('btc', 27),
#  ('crypto', 23),
#  ('wa', 22),
#  ('cryptocurrency', 21),
#  ('price', 16),
#  ('last', 12),
#  ('mining', 12),
#  ('first', 11)]

# %%
# Use token_count to get the top 10 words for Ethereum
# Create empty list which will hold tokens from all articles 
ethereum_all_tokens = []

# Loop through tokens from all articles and add into all_tokens list
for tokens in ethereum_tokens_df["Tokens"]:
    ethereum_all_tokens += tokens

# Use the token_count function to retun the top 10 words and counts  
ethereum_top10_words = token_count(ethereum_all_tokens)
ethereum_top10_words
# Out:
# [('ethereum', 35),
#  ('cryptocurrency', 30),
#  ('crypto', 20),
#  ('eth', 19),
#  ('market', 18),
#  ('bitcoin', 16),
#  ('wa', 15),
#  ('one', 14),
#  ('million', 13),
#  ('blockchain', 12)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud for the top 50 words
bitcoin_big_string = ' '.join(bitcoin_all_tokens)
wc = WordCloud(width=1200, height=800, max_words=50).generate(bitcoin_big_string)
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud for the top 50 words
ethereum_big_string = ' '.join(ethereum_all_tokens)
wc = WordCloud(width=1200, height=800, max_words=50).generate(ethereum_big_string)
plt.imshow(wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
# Create empty list which will hold the text from all articles 
bitcoin_text = []

# Loop through the text column for all articles and add into bitcoin_text list
for text in bitcoin_tokens_df['Text']:
    # Create Bitcoin Text List
    text_list = text
    # Add article text to list
    bitcoin_text.append(text_list)

# Join the items in the bitcoin_text list into one big string    
bitcoin_all_text_big_string = ' '.join(bitcoin_text)

# Inspect bitcoin_all_text_big_string
bitcoin_all_text_big_string
# Out:
# "in a new blog post the company said that 4,836 eth and 443 bitcoin were taken\r\nillustration by alex castro / the verge\r\nin a blog post published in the early hours of thursday morning, cryptocurrency… [+2004 chars] london, jan 7 (reuters) - bitcoin on friday slumped as much as 5% to its lowest since late september, tumbling under $41,000 amid a broader sell-off for cryptocurrencies.\r\nbitcoin was last down 3.7% … [+1419 chars] ** shares of cryptocurrency and blockchain-related firms fall after bitcoin briefly slides below $40,000 to a 5-month low\r\n** the world's largest digital asset was last down 2.6% at $40,800 after fal… [+1132 chars] welcome to kitco news' 2022 outlook series. the new year will be filled with uncertainty as the federal reserve looks to pivot and tighten its monetary policies. at the same time, the inflation threa… [+2832 chars] after one of roughest patches ever for bitcoin enthusiasts, holders of the largest digital currency are facing an ominous technical price pattern with a name that suggests more pain ahead.\xa0\r\nknown as… [+3529 chars] bitcoin slumped wednesday and into thursday.jirapong manustrong/getty images\r\nbitcoin was down more than 8% thursday, and the cryptocurrency market was a sea of red, after minutes revealed the federa… [+2331 chars] in an interview with bloomberg tv, crypto.com's chief executive kris marszalek has admitted that 400 customer accounts were compromised by hackers. he said his team detected unauthorized transactions… [+2811 chars] london, jan 14 (reuters) - kazakhstan may no longer be the bitcoin sanctuary it once was, according to some big miners who are looking to leave the global crypto hub following internet shutdowns last… [+4521 chars] san pedro de poas, costa rica (reuters) - a small river in the middle of coffee plantations, sugar cane fields and a forest provides energy to a hydroelectric power plant in costa rica that feeds hun… [+2330 chars] (bloomberg) -- after one of the roughest patches ever for bitcoin enthusiasts, holders of the largest digital currency are facing an ominous technical price pattern with a name that suggests more pai… [+4176 chars] investing in crypto is a risky business particularly when youre betting with a countrys future. its nonetheless a gamble that el salvadors president has been eager to make.\r\nnayib bukeles splurging o… [+6581 chars] i show how price manipulation to liquidate traders is done in cryptocurrency markets. i point fingers at people. thanks to coinstrats for allowing me to use their order book data for the analysis. al… [+21971 chars] every bitcoin transaction is stored in the distributed database known as the bitcoin blockchain.\r\nhowever, people have found ways to hack the bitcoin protocol to store more than just transactions. i'… [+25681 chars] today i counted no fewer than 14 individuals doing this (based on unique ethereum and bitcoin addresses, address reuse, unique videos, registrar info, and unique domains), stealing roughly $200k in t… [+3258 chars] when can something bad also be used for good? the answer is crypto mining! \xa0\r\ntraditional crypto mining is notoriously resource-intensive with the annual carbon footprint of mining bitcoin equivalent… [+4569 chars] note: this is not investment advice and my investment disclosures are below.\r\nspecial thanks to my ali khan for running the scripts to grab and analyze pricing data. hes looking for an internship so … [+23280 chars] just two months ago, bitcoin and global crypto markets seemed hotter than ever: 1 btc was worth nearly $68,000, bringing its total market cap to $1.27 trillion; crypto’s global market cap was a mind-… [+4821 chars] the european union urgently needs to ban a form of cryptocurrency mining that is relying heavily on renewable energy, and poses a threat to climate-change goals, a top regional regulator said wednesd… [+3564 chars] coinbase launched the first in a series of payroll offerings:\r\nproud of the team for continuing to ...

# %%
# Run the NER processor on all of the text
bitcoin_ner = nlp(bitcoin_all_text_big_string)

# Add a title to the document
bitcoin_ner.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(bitcoin_ner, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">in a new blog post the company said that
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4,836
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  eth and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     443
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>illustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     alex castro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>in a blog post published in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the early hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , cryptocurrency… [+2004 chars]
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     london
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jan 7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - bitcoin on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  slumped
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     as much as 5%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  to its lowest since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     late september
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , tumbling under $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     41,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>bitcoin was last down
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.7%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  … [+1419 chars] ** shares of cryptocurrency and blockchain-related firms fall after bitcoin briefly slides below $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     40,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  to a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5-month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>** the world's largest digital asset was last down
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2.6%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  at $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     40,800
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  after fal… [+1132 chars] welcome to kitco news'
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  outlook series.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the new year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  will be filled with uncertainty as the federal reserve looks to pivot and tighten its monetary policies. at the same time, the inflation threa… [+2832 chars] after
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>known as… [+3529 chars] bitcoin slumped
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>bitcoin was down
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than 8%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thursday
#     <span style="font-

# %%
# List all Entities
bitcoin_ents = set([ent.text for ent in bitcoin_ner.ents ])
bitcoin_ents
# Out:
# {'$1 million',
#  '$1.27 trillion',
#  '$1.4 trillion',
#  '$25 million',
#  '$43.2 million',
#  '$9 trillion',
#  '+0.12',
#  '+0.52%',
#  '+11.34%',
#  '+1773',
#  '+1798',
#  '+2402',
#  '+3049',
#  '+3835',
#  '+4176',
#  '-1.71%',
#  '1',
#  '1,000',
#  '1.11%',
#  '1.54%',
#  '1.93%',
#  '100',
#  '10:38',
#  '1808',
#  '1982',
#  '1:30 p.m.',
#  '2',
#  '2%',
#  '2.6%',
#  '2009',
#  '2013',
#  '2020',
#  '2021',
#  '2022',
#  '22.5%',
#  '25th july',
#  '265',
#  '270',
#  '276',
#  '2955',
#  '3,146',
#  '3.7%',
#  '3.8',
#  '38,180',
#  '395 per cent',
#  '4',
#  '4%',
#  '4,836',
#  '40,000',
#  '40,800',
#  '400',
#  '40569',
#  '41,000',
#  '41,900',
#  '42,000',
#  '44-year-old',
#  '443',
#  '4501',
#  '462.1',
#  '484.5',
#  '4th',
#  '5,296',
#  '5,518',
#  '5-month',
#  '50',
#  '500',
#  '60',
#  '660',
#  '67,000',
#  '68%',
#  '68,999.99',
#  '8',
#  '] miami',
#  'a good year',
#  'about $230 million.</li><li',
#  'about $48,0',
#  'about $80',
#  'about 12%',
#  'about 30%',
#  'above $38,000',
#  'alex castro',
#  'alex kantrowitz',
#  'ali khan',
#  'amazon',
#  'andre iguodala',
#  'april 5th 2021',
#  'around $1.5 trillion',
#  'around $36,500',
#  'as much as 5%',
#  'bitcoin(crypto',
#  'block(nyse',
#  'blockchai',
#  'bloomberg',
#  'bloomberg tv',
#  'brad',
#  'canadian',
#  'casa',
#  'changpeng ‘',
#  'chinas',
#  'costa rica',
#  'crypto',
#  'daily',
#  'day',
#  'december',
#  'december 1',
#  'dubai',
#  'early afternoon',
#  'early monday',
#  'early november',
#  'el salvador',
#  'el salvadors',
#  'etfs',
#  'fed',
#  'first',
#  'florida',
#  'friday',
#  'getty\r\nwall …',
#  'half',
#  'intraday',
#  'jacob &amp; co.',
#  'jan 14',
#  'jan 7',
#  'january',
#  'joe raedle',
#  'july this morning',
#  'just two months ago',
#  'kazakhstan',
#  'kmr images',
#  'kris marszalek',
#  'last month',
#  'last week',
#  'last weeks',
#  'late last year',
#  'late september',
#  'late-afternoon',
#  'latin american',
#  'london',
#  'los angeles',
#  'mara',
#  'march 9th',
#  'michael saylor',
#  'minutes',
#  'monday',
#  'more than 8%',
#  'morning',
#  'nayib',
#  'nearly $200 billion',
#  'nearly $68,000',
#  'nearly a week-long',
#  'next month',
#  'november',
#  'november 10, 2021',
#  'october',
#  'one',
#  'only 1%',
#  'over 1,000',
#  'over 125,000',
#  'over 2%',
#  'overnight',
#  'recent months',
#  'registrar info',
#  'reuters',
#  'roughly $200k',
#  'roughly $3 trillion',
#  'saturday',
#  'september of last',
#  'shuang paul wang',
#  'six-day',
#  'six-month',
#  'some 7%',
#  'spain',
#  'sub-$35,000',
#  'subscribe',
#  'summer',
#  'ten-year',
#  'that day',
#  'the bank of england',
#  'the day',
#  'the december minutes',
#  'the early hours',
#  'the end of last year',
#  'the european union',
#  'the federal reserve',
#  'the first week of january',
#  'the first week of the year',
#  'the last several hours',
#  'the minutes',
#  'the new year',
#  'the past 24 hours',
#  'the past few months',
#  'the past few years',
#  'the previous month',
#  'the two months',
#  'the week',
#  'the weekend',
#  'the year',
#  'this day',
#  'this month',
#  'this week',
#  'thompson',
#  'three',
#  'thursday',
#  'today',
#  'treasury',
#  'tuesday',
#  'two',
#  'two months',
#  'two-month',
#  'two-week',
#  'u.k.-based',
#  'u.s.',
#  'wednesday',
#  'wilday'}

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
# Create empty list which will hold the text from all articles 
ethereum_text = []

# Loop through the text column for all articles and add into ethereum_text list
for text in ethereum_tokens_df['Text']:
    # Create Ethereum Text List
    text_list = text
    # Add article text to list
    ethereum_text.append(text_list)

# Join the items in the ethereum_text list into one big string    
ethereum_all_text_big_string = ' '.join(ethereum_text)

# Inspect ethereum_all_text_big_string
ethereum_all_text_big_string
# Out:
# 'in a new blog post the company said that 4,836 eth and 443 bitcoin were taken\r\nillustration by alex castro / the verge\r\nin a blog post published in the early hours of thursday morning, cryptocurrency… [+2004 chars] in an interview with bloomberg tv, crypto.com\'s chief executive kris marszalek has admitted that 400 customer accounts were compromised by hackers. he said his team detected unauthorized transactions… [+2811 chars] online thieves made off with "wrapped ethereum" worth nearly $324 million.\r\ngetty images\r\nhackers stole more than $324 million in cryptocurrency from wormhole, the developers behind the popular block… [+1664 chars] online thieves made off with 120,000 weth, or wrapped ethereum, worth nearly $324 million.\r\ngetty images\r\nhackers have stolen more than $324 million in cryptocurrency from wormhole, the developers be… [+1553 chars] the crypto market\'s whiplash volatility\xa0can make investing in certain coins feel like a major gamble, especially to those less familiar\xa0with the ins and outs of digital wallets and blockchain technol… [+1986 chars] the bug appears to have been present for weeks and seems to be referenced in at least one tweet from january 1st, 2022. but exploitation of the bug has picked up significantly in the past day: blockc… [+1179 chars] a version of this article was published in time’s newsletter into the metaverse. subscribe for a weekly guide to the future of the internet.you can find past issues of the newsletter here.\r\nwhen vita… [+9697 chars] ethereum is a protocol undergoing significant changes. client teams are upgrading the protocol to scale to meet global demand while improving security and decentralization. beyond protocol developmen… [+5874 chars] after exploiting a wormhole vulnerability, hackers stole around $322 million from solana (sol), but the interoperability protocol has recently updated its users that the funds have been restored.\r\nac… [+1807 chars] crypto.com, a singapore-based cryptocurrency exchange, has denied reports that the firm lost nearly $15m in ethereum in a possible network intrusion over the weekend.\r\naccording to blockchain biz pec… [+2208 chars] the color museum wants to monetize the building blocks of nft avatars by licensing out the exclusive rights to specific hexadecimal colors on the blockchain, which you can select and name yourself. i… [+2019 chars] in 2022, ethereum stands as the second-most valuable cryptocurrency behind bitcoin. thousands of people buy and sell ethereum every day, but owning ethereum requires storing your private keys securel… [+8900 chars] today i counted no fewer than 14 individuals doing this (based on unique ethereum and bitcoin addresses, address reuse, unique videos, registrar info, and unique domains), stealing roughly $200k in t… [+3258 chars] weth is an erc20 token that is designed to have the same value as eth, essentially just erc20-ifying eth. all erc20 tokens are essentially just smart contracts (little computer programs that are host… [+1429 chars] crypto.com has just recognized that were was a cyber attack on its platform. \r\nusers were brought on to the news when their accounts suddenly required two-factor authentication sign-in, along with pa… [+489 chars] on thursday night, crypto twitter was overrun with people begging others to click their referral links for something called wtf. if you saw any of the many groveling tweets, you may have been wonderi… [+5180 chars] a hacker who stole more than $1 million from users of a cryptocurrency platform and then promised to return it keeping a tip for their services has kept their word.\r\non wednesday, a hacker that calle… [+3913 chars] if you own a high-performance gaming computer or graphics workstation, the chances are youre sitting on an untapped revenue stream. cryptocurrency mining, or more specifically ethereum mining, has be… [+18105 chars] a charity dedicated to eradicating medical debt is facing criticism online after accepting donation ...

# %%
# Run the NER processor on all of the text
ethereum_ner = nlp(ethereum_all_text_big_string)

# Add a title to the document
ethereum_ner.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(ethereum_ner, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">in a new blog post the company said that
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4,836
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  eth and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     443
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>illustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     alex castro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>in a blog post published in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the early hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , cryptocurrency… [+2004 chars] in an interview with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bloomberg tv
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , crypto.com's chief executive
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kris marszalek
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has admitted that
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     400
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  customer accounts were compromised by hackers. he said his team detected unauthorized transactions… [+2811 chars] online thieves made off with &quot;wrapped ethereum&quot; worth
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly $324 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>hackers stole
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than $324 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in cryptocurrency from wormhole, the developers behind the popular block… [+1664 chars] online thieves made off with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     120,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  weth, or wrapped ethereum, worth
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly $324 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>hackers have stolen
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than $324 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in cryptocurrency from wormhole, the developers be… [+1553 chars] the crypto market's whiplash volatility can make investing in certain coins feel like a major gamble, especially to those less familiar with the ins and outs of digital wallets and blockchain technol… [+1986 chars] the bug appears to have been present for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and seems to be referenced in
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     at least one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  tweet from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     january 1st
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . but exploitation of the bug has picked up significantly in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# : blockc… [+1179 chars] a version of this article was published in time’s newsletter into the metaverse. subscribe for a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     weekly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>when vita… [+9697 chars] ethereum is a protocol undergoing significant changes. client teams are upgrading the protocol to scale to meet global demand while improving security and decentralization. beyond protocol developmen… [+5874 chars] after exploiting a wormhole vulnerability, hackers stole around
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $322 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left

# %%
# List all Entities
ethereum_ents = set([ent.text for ent in ethereum_ner.ents ])
ethereum_ents
# Out:
# {'$1.27 trillion',
#  '$1.4 trillion',
#  '$10 million',
#  '$15 billion',
#  '$15 million',
#  '$250 million',
#  '$322 million',
#  '$325 million',
#  '+0.12',
#  '+0.52%',
#  '+11.34%',
#  '+1112',
#  '+3049',
#  '+3176',
#  '+5936',
#  '0.95',
#  '1',
#  '1.20',
#  '1.93%',
#  '12-month',
#  '12.62%',
#  '120,000',
#  '120k',
#  '1808',
#  '2,400',
#  '2,450',
#  '200',
#  '2009',
#  '2021',
#  '2022',
#  '25%',
#  '27 days',
#  '2955',
#  '3,000',
#  '3,120',
#  '3,376',
#  '30',
#  '3000',
#  '3050',
#  '36.2%',
#  '360',
#  '4,000',
#  '4,600',
#  '4,836',
#  '4.3',
#  '40 acres',
#  '40,000',
#  '400',
#  '40569',
#  '409%',
#  '443',
#  '4501',
#  '500',
#  '60',
#  '615',
#  '7000',
#  '80%',
#  '90',
#  '90 day',
#  'a whirlwind few weeks',
#  'about $2,300',
#  'about $2.3 million',
#  'about $320m',
#  'about 4%',
#  'accordi',
#  'alex castro',
#  'alex kantrowitz',
#  'ali khan',
#  'amazon',
#  'an estimated $322',
#  'an estimated 4,600',
#  'an ethereum year-end',
#  'an uncertain weekend',
#  'around $320 million',
#  'as of jan. 27',
#  'at least $15 million',
#  'at least one',
#  'bloomberg tv',
#  'chris macdonald',
#  'close to $34,000',
#  'crypto',
#  'crypto bluechips',
#  'cryptocurrencies',
#  'daily',
#  'day',
#  'earlier this week',
#  'earlier today',
#  'early november',
#  'eric adams',
#  'ethereum(crypto',
#  'evan van ness',
#  'evening',
#  'every day',
#  'february 1st',
#  'fed',
#  'fees.wtf',
#  'first',
#  'intraday',
#  'its initial week',
#  'january 1st',
#  'january 26',
#  'jim iuorio',
#  'just two months ago',
#  'kmr images',
#  'kris marszalek',
#  'last week',
#  'last year',
#  'late thursday',
#  'london',
#  'maison',
#  'manhattan',
#  'march',
#  'march 9th',
#  'millions',
#  'monday',
#  'more than $1 million',
#  'more than $14 million',
#  'more than $320 million',
#  'more than $324 million',
#  'more than 50%',
#  'morning',
#  'multimillion-dollar',
#  'nearly $15m',
#  'nearly $324 million',
#  'nearly $68,000',
#  'new york city',
#  'norton',
#  'norton 360',
#  'one',
#  'overnight',
#  'quantum',
#  'registrar info',
#  'rez',
#  'rez x visual',
#  'roughly $200k',
#  'roughly $3 trillion',
#  'second',
#  'september',
#  'september 30',
#  'serena williams',
#  'singapore',
#  'skyr',
#  'solana blockchain &',
#  'ten-year',
#  'the early hours',
#  "the federal reserve's",
#  'the new year',
#  'the past 24 hours',
#  'the past 24-hours',
#  'the past day',
#  'the past few years',
#  'the past three- and five-year',
#  'the weekend',
#  'the year',
#  'the years',
#  'this past year',
#  'this year',
#  'this\xa0jan. 19',
#  'thousands',
#  'three',
#  'thursday',
#  'thursday night',
#  'today',
#  'todd kramer',
#  'treasury',
#  'two',
#  'two-month',
#  'u.s.',
#  'wednesday',
#  'weekly',
#  'weeks',
#  'wolf',
#  'yesterday'}

# %% [markdown]
# ---
